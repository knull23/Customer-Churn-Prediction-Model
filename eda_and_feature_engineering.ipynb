# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
X_train = pd.read_csv("data/X_train_sm.csv")
y_train = pd.read_csv("data/y_train_sm.csv")
X_test = pd.read_csv("data/X_test.csv")
y_test = pd.read_csv("data/y_test.csv")

# %%
# Combine features and target for easier EDA
df_train = pd.concat([X_train, y_train], axis=1)

# %%
# Check the structure of the dataset
print("Training Dataset Shape:", df_train.shape)
print("\nTraining Dataset Info:")
print(df_train.info())
print("\nTraining Dataset Head:")
print(df_train.head())
# Out:
# Training Dataset Shape: (8330, 46)
#
# Training Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8330 entries, 0 to 8329
# Data columns (total 46 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        8330 non-null   float64
#  1   Gender                             8330 non-null   float64
#  2   Age                                8330 non-null   float64
#  3   Under 30                           8330 non-null   float64
#  4   Senior Citizen                     8330 non-null   float64
#  5   Married                            8330 non-null   float64
#  6   Dependents                         8330 non-null   float64
#  7   Number of Dependents               8330 non-null   float64
#  8   Country                            8330 non-null   float64
#  9   State                              8330 non-null   float64
#  10  City                               8330 non-null   float64
#  11  Zip Code                           8330 non-null   float64
#  12  Latitude                           8330 non-null   float64
#  13  Longitude                          8330 non-null   float64
#  14  Population                         8330 non-null   float64
#  15  Quarter                            8330 non-null   float64
#  16  Referred a Friend                  8330 non-null   float64
#  17  Number of Referrals                8330 non-null   float64
#  18  Tenure in Months                   8330 non-null   float64
#  19  Phone Service                      8330 non-null   float64
#  20  Avg Monthly Long Distance Charges  8330 non-null   float64
#  21  Multiple Lines                     8330 non-null   float64
#  22  Internet Service                   8330 non-null   float64
#  23  Avg Monthly GB Download            8330 non-null   float64
#  24  Online Security                    8330 non-null   float64
#  25  Online Backup                      8330 non-null   float64
#  26  Device Protection Plan             8330 non-null   float64
#  27  Premium Tech Support               8330 non-null   float64
#  28  Streaming TV                       8330 non-null   float64
#  29  Streaming Movies                   8330 non-null   float64
#  30  Streaming Music                    8330 non-null   float64
#  31  Unlimited Data                     8330 non-null   float64
#  32  Contract                           8330 non-null   float64
#  33  Paperless Billing                  8330 non-null   float64
#  34  Payment Method                     8330 non-null   float64
#  35  Monthly Charge                     8330 non-null   float64
#  36  Total Charges                      8330 non-null   float64
#  37  Total Refunds                      8330 non-null   float64
#  38  Total Extra Data Charges           8330 non-null   float64
#  39  Total Long Distance Charges        8330 non-null   float64
#  40  Total Revenue                      8330 non-null   float64
#  41  Satisfaction Score                 8330 non-null   float64
#  42  Customer Status                    8330 non-null   float64
#  43  Churn Score                        8330 non-null   float64
#  44  CLTV                               8330 non-null   float64
#  45  Churn                              8330 non-null   int64
# dtypes: float64(45), int64(1)
# memory usage: 2.9 MB
# None
#
# Training Dataset Head:
#    Customer ID    Gender       Age  Under 30  Senior Citizen   Married  \
# 0    -0.130535  1.174445 -0.656616 -0.409848        -0.38555 -0.766928
# 1     1.049439  1.174445  0.400386 -0.409848        -0.38555 -0.766928
# 2    -1.154720  1.174445 -1.464912  2.439929        -0.38555  1.303903
# 3    -1.437150  1.174445 -1.527088  2.439929        -0.38555 -0.766928
# 4    -0.659714 -0.851466 -0.407910 -0.409848        -0.38555  1.303903
#
#    Dependents  Number of Dependents  Country  State  ...  Total Charges  \
# 0   -0.431592             -0.401582      0.0    0.0  ...       0.486577
# 1   -0.431592             -0.401582      0.0    0.0  ...      -0.913126
# 2    2.317003              0.804322      0.0    0.0  ...      -0.580880
# 3   -0.431592             -0.401582      0.0    0.0  ...      -0.675387
# 4   -0.431592             -0.401582      0.0    0.0  ...      -0.036483
#
#    Total Refunds  Total Extra Data Charges  Total Long Distance Charges  \
# 0      -0.251417                 -0.292944                     0.323439
# 1      -0.251417                 -0.292944                    -0.805356
# 2      -0.251417                 -0.292944                     1.009742
# 3      -0.251417                  0.133259                    -0.614377
# 4      -0.251417                 -0.292944                     0.666445
#
#    Total Revenue  Satisfaction Score  Customer Status  Churn Score      CLTV  \
# 0       0.471560           -1.226290        -0.979501     0.730479  1.394219
# 1      -0.947571           -1.226290        -0.979501     1.306150  0.375136
# 2      -0.163983            0.251040         1.066191    -0.804643 -0.319497
# 3      -0.703096            0.251040        -0.979501     0.442643 -0.846728
# 4       0.162078            0.989705         1.066191    -2.147875  0.375136
#
#    Churn
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#
# [5 rows x 46 columns]

# %%
categorical_cols = [col for col in df_train.columns if df_train[col].nunique() <= 10]

print("Categorical columns based on unique values:")
print(categorical_cols)
# Out:
# Categorical columns based on unique values:
# ['Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Number of Dependents', 'Country', 'State', 'Quarter', 'Referred a Friend', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection Plan', 'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing', 'Payment Method', 'Satisfaction Score', 'Customer Status', 'Churn']

# %%
if len(categorical_cols) == 0:
    print("\nNo categorical columns to summarize — dataset is fully numeric after preprocessing.")
else:
    print("\nCategorical Features Summary:")
    print(df_train[categorical_cols].describe())
# Out:
# Categorical Features Summary:
#              Gender      Under 30  Senior Citizen       Married    Dependents  \
# count  8.330000e+03  8.330000e+03    8.330000e+03  8.330000e+03  8.330000e+03
# mean   4.947356e-17  8.529925e-19    4.734108e-17  1.398908e-16 -7.506334e-17
# std    1.000060e+00  1.000060e+00    1.000060e+00  1.000060e+00  1.000060e+00
# min   -8.514663e-01 -4.098479e-01   -3.855498e-01 -7.669284e-01 -4.315921e-01
# 25%   -8.514663e-01 -4.098479e-01   -3.855498e-01 -7.669284e-01 -4.315921e-01
# 50%   -8.514663e-01 -4.098479e-01   -3.855498e-01 -7.669284e-01 -4.315921e-01
# 75%    1.174445e+00 -4.098479e-01   -3.855498e-01  1.303903e+00 -4.315921e-01
# max    1.174445e+00  2.439929e+00    2.593699e+00  1.303903e+00  2.317003e+00
#
#        Number of Dependents  Country   State  Quarter  Referred a Friend  ...  \
# count          8.330000e+03   8330.0  8330.0   8330.0       8.330000e+03  ...
# mean           1.108890e-17      0.0     0.0      0.0      -9.553516e-17  ...
# std            1.000060e+00      0.0     0.0      0.0       1.000060e+00  ...
# min           -4.015818e-01      0.0     0.0      0.0      -7.325414e-01  ...
# 25%           -4.015818e-01      0.0     0.0      0.0      -7.325414e-01  ...
# 50%           -4.015818e-01      0.0     0.0      0.0      -7.325414e-01  ...
# 75%           -4.015818e-01      0.0     0.0      0.0       1.365111e+00  ...
# max            1.045155e+01      0.0     0.0      0.0       1.365111e+00  ...
#
#        Streaming TV  Streaming Movies  Streaming Music  Unlimited Data  \
# count  8.330000e+03      8.330000e+03     8.330000e+03    8.330000e+03
# mean  -5.501801e-17     -2.303080e-17    -4.264962e-17   -1.322138e-16
# std    1.000060e+00      1.000060e+00     1.000060e+00    1.000060e+00
# min   -6.946007e-01     -6.976414e-01    -6.279933e-01   -1.409515e+00
# 25%   -6.946007e-01     -6.976414e-01    -6.279933e-01   -1.409515e+00
# 50%   -6.946007e-01     -6.976414e-01    -6.279933e-01    7.094637e-01
# 75%    1.439676e+00      1.433401e+00     1.592374e+00    7.094637e-01
# max    1.439676e+00      1.433401e+00     1.592374e+00    7.094637e-01
#
#            Contract  Paperless Billing  Payment Method  Satisfaction Score  \
# count  8.330000e+03       8.330000e+03    8.330000e+03        8.330000e+03
# mean   3.411970e-18       1.183527e-17    6.312144e-17       -9.382917e-17
# std    1.000060e+00       1.000060e+00    1.000060e+00        1.000060e+00
# min   -6.767885e-01      -1.169539e+00   -6.896479e-01       -1.226290e+00
# 25%   -6.767885e-01      -1.169539e+00   -6.896479e-01       -1.226290e+00
# 50%   -6.767885e-01       8.550374e-01   -6.896479e-01        2.510397e-01
# 75%    6.030408e-01       8.550374e-01    1.087267e+00        9.897047e-01
# max    1.882870e+00       8.550374e-01    2.864183e+00        1.728370e+00
#
#        Customer Status       Churn
# count     8.330000e+03  8330.00000
# mean     -2.388379e-17     0.50000
# std       1.000060e+00     0.50003
# min      -9.795010e-01     0.00000
# 25%      -9.795010e-01     0.00000
# 50%      -4.680780e-01     0.50000
# 75%       1.066191e+00     1.00000
# max       1.066191e+00     1.00000
#
# [8 rows x 27 columns]

# %%
df_original = pd.read_csv("data/telco.csv")
print("\nOriginal Dataset Data Types:")
print(df_original.dtypes)
# Out:
# Original Dataset Data Types:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Under 30                              object
# Senior Citizen                        object
# Married                               object
# Dependents                            object
# Number of Dependents                   int64
# Country                               object
# State                                 object
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Population                             int64
# Quarter                               object
# Referred a Friend                     object
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download                int64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# Premium Tech Support                  object
# Streaming TV                          object
# Streaming Movies                      object
# Streaming Music                       object
# Unlimited Data                        object
# Contract                              object
# Paperless Billing                     object
# Payment Method                        object
# Monthly Charge                       float64
# Total Charges                        float64
# Total Refunds                        float64
# Total Extra Data Charges               int64
# Total Long Distance Charges          float64
# Total Revenue                        float64
# Satisfaction Score                     int64
# Customer Status                       object
# Churn Label                           object
# Churn Score                            int64
# CLTV                                   int64
# Churn Category                        object
# Churn Reason                          object
# dtype: object
